# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
cd /content/gdrive/My Drive/tobigs_recommend/Phase v2. Recsys2019 Deep Modeling
# Out:
# /content/gdrive/My Drive/tobigs_recommend/Phase v2. Recsys2019 Deep Modeling

# %%
# !git clone https://github.com/rec-agent/rec-rl.git
# Out:
# Cloning into 'rec-rl'...
# remote: Enumerating objects: 215, done.
# remote: Total 215 (delta 0), reused 0 (delta 0), pack-reused 215
# Receiving objects: 100% (215/215), 322.03 KiB | 4.24 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
cd /content/gdrive/My Drive/tobigs_recommend/Phase v2. Recsys2019 Deep Modeling/rec-rl
# Out:
# /content/gdrive/My Drive/tobigs_recommend/Phase v2. Recsys2019 Deep Modeling/rec-rl
